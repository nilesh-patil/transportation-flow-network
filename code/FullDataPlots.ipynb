# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/public/npatil4/networks/data/combined/decimal3/data_2015_withNodes_hour.txt'

data_hour = pd.read_csv(file_path,
                        sep='|')

# %%
rows = data_hour[1:10**7].index

Y = data_hour.charge[rows]/data_hour.duration[rows]
X = data_hour.duration[rows]


sns.plt.figure(figsize=(8,8))
sns.set_style('whitegrid')
sns.plt.scatter(y=Y,x=X,alpha=0.1)

sns.plt.xlim((0,10000))
sns.plt.ylim((0,300))

sns.plt.title('Cost vs Duration')
sns.plt.xlabel('Duration (s)')
sns.plt.ylabel('Cost ($)')

plt.savefig('../plots/CostVsDuration.png',dpi=900)
